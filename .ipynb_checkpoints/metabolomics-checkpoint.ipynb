# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#pip install spectrum_utils

# %%
#pip install pyteomics

# %%
#!pip install rdkit

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import DataStructs

# %%
import logging
from typing import Dict, IO, Iterator, Sequence, Union
from pyteomics import mgf
import pyteomics
from spectrum_utils.spectrum import MsmsSpectrum
import matplotlib.pyplot as plt
import spectrum_utils.plot as sup
import spectrum_utils as su
import numpy as np
from src.load_data import LoadData
from spectrum_utils import plot
from src.preprocessor import Preprocessor
from src.ml_model import MlModel
from src.tanimoto import Tanimoto
from sklearn.model_selection import train_test_split
from src.plotting import Plotting
import pickle
from src.cosine_distance import CosineDistance

# %%
from tqdm import tqdm

# %%
from src.spectrum_ext import SpectrumExt

# %%
from src.train_utils import TrainUtils
from sklearn.metrics import r2_score

# %%
pp =Preprocessor()

# %%
## THINGS TO DO:
# ADD ADITIONAL VARIABLES TO VECTOR
# TRAIN FOR MORE TIME

# %% [markdown]
# ## Parameters

# %%
mgf_path = r"C:\Users\ramir\Downloads\ALL_GNPS_NO_PROPOGATED.mgf"

# %% [markdown]
# ## Load data + preprocessing

# %%
all_spectrums_original = LoadData.get_all_spectrums(mgf_path,1000000)
# Out:
#  34%|███▍      | 344112/1000000 [02:19<03:25, 3186.50it/s]

# %%
len(all_spectrums_original)

# %%
#preprocess 
all_spectrums = pp.preprocess_all_spectrums(all_spectrums_original)

# %%
len(all_spectrums)

# %% [markdown]
# ## Divide data into training/test  + computing similarity score

# %%
# divide train and test
all_spectrums_train, all_spectrums_test = train_test_split(all_spectrums)

# %%
molecule_pairs_train= TrainUtils.compute_all_tanimoto_results(all_spectrums_train, max_combinations=10**5)

# %%
molecule_pairs_test = TrainUtils.compute_all_tanimoto_results(all_spectrums_test, max_combinations=10**5)

# %% [markdown]
# ## Save data

# %%
#import pickle
# Dump the dictionary to a file using pickle

#dataset ={'all_spectrums_train':all_spectrums_train,
#          'all_spectrums_test': all_spectrums_test,
#          'molecule_pairs_train':molecule_pairs_train,
#          'molecule_pairs_test': molecule_pairs_test,
#         }
#with open('./dataset_processed.pkl', 'wb') as file:
#    pickle.dump(dataset, file)

# %% [markdown]
# ## Load data

# %%
#import pickle

# Load the dataset from the pickle file
#with open('./dataset_processed.pkl', 'rb') as file:
#    dataset = pickle.load(file)

# Now you can access the original variables from the dataset dictionary
#all_spectrums_train = dataset['all_spectrums_train']
#all_spectrums_test = dataset['all_spectrums_test']
#molecule_pairs_train = dataset['molecule_pairs_train']
#molecule_pairs_test = dataset['molecule_pairs_test']

# %% [markdown]
# ## Balance the data

# %%
plt.hist([m.similarity for m in molecule_pairs_train], bins=3)

# %%
# get a uniform distribution of taminoto scores
uniformed_molecule_pairs_train =TrainUtils.uniformise(molecule_pairs_train)

# %%
_=plt.hist([m.similarity for m in uniformed_molecule_pairs_train], bins=3)

# %% [markdown]
# ## Train Siamese model

# %%
model = MlModel(input_dim=all_spectrums_train[0].spectrum_vector.shape[0])

# %%
model.compile()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 991)]                0         []
#
#  input_2 (InputLayer)        [(None, 2)]                  0         []
#
#  input_3 (InputLayer)        [(None, 991)]                0         []
#
#  input_4 (InputLayer)        [(None, 2)]                  0         []
#
#  model (Functional)          (None, 32)                   5729      ['input_1[0][0]',
#                                                                      'input_2[0][0]',
#                                                                      'input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  cosine_similarity (Dot)     (None, 1)                    0         ['model[0][0]',
#                                                                      'model[1][0]']
#
# ==================================================================================================
# Total params: 5729 (22.38 KB)
# Trainable params: 5601 (21.88 KB)
# Non-trainable params: 128 (512.00 Byte)
# __________________________________________________________________________________________________

# %%
model.fit(uniformed_molecule_pairs_train, epochs=100)
# Out:
# Epoch 1/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1183 - mse: 0.1183
# Epoch 1: val_mse improved from inf to 0.03687, saving model to best_model.h5
# 97/97 [==============================] - 24s 155ms/step - loss: 0.1183 - mse: 0.1183 - val_loss: 0.0369 - val_mse: 0.0369
# C:\Users\ramir\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1082 - mse: 0.1082
# Epoch 2: val_mse improved from 0.03687 to 0.03687, saving model to best_model.h5
# 97/97 [==============================] - 13s 135ms/step - loss: 0.1082 - mse: 0.1082 - val_loss: 0.0369 - val_mse: 0.0369
# Epoch 3/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1050 - mse: 0.1050
# Epoch 3: val_mse improved from 0.03687 to 0.03685, saving model to best_model.h5
# 97/97 [==============================] - 12s 123ms/step - loss: 0.1050 - mse: 0.1050 - val_loss: 0.0369 - val_mse: 0.0369
# Epoch 4/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1067 - mse: 0.1067
# Epoch 4: val_mse improved from 0.03685 to 0.03681, saving model to best_model.h5
# 97/97 [==============================] - 12s 128ms/step - loss: 0.1067 - mse: 0.1067 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 5/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1057 - mse: 0.1057
# Epoch 5: val_mse improved from 0.03681 to 0.03680, saving model to best_model.h5
# 97/97 [==============================] - 11s 118ms/step - loss: 0.1060 - mse: 0.1060 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 6/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1011 - mse: 0.1011
# Epoch 6: val_mse did not improve from 0.03680
# 97/97 [==============================] - 11s 119ms/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 7/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.0991 - mse: 0.0991
# Epoch 7: val_mse did not improve from 0.03680
# 97/97 [==============================] - 12s 126ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 8/100
# 97/97 [==============================] - ETA: 0s - loss: 0.1020 - mse: 0.1020
# Epoch 8: val_mse did not improve from 0.03680
# 97/97 [==============================] - 14s 141ms/step - loss: 0.1020 - mse: 0.1020 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 9/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1001 - mse: 0.1001
# Epoch 9: val_mse did not improve from 0.03680
# 97/97 [==============================] - 12s 127ms/step - loss: 0.1002 - mse: 0.1002 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 10/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1048 - mse: 0.1048
# Epoch 10: val_mse did not improve from 0.03680
# 97/97 [==============================] - 12s 120ms/step - loss: 0.1047 - mse: 0.1047 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 11/100
# 96/97 [============================>.] - ETA: 0s - loss: 0.1016 - mse: 0.1016
# Epoch 11: val_mse did not improve from 0.03680
# 97/97 [==============================] - 12s 124ms/step - loss: 0.1014 - mse: 0.1014 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 12/100
# 15/97 [===>..........................] - ETA: 6s - loss: 0.1018 - mse: 0.1018
# KeyboardInterrupt

# %%
model.load_best_model()

# %% [markdown]
# ## Evaluate performance

# %%
prediction_results_train = model.predict(uniformed_molecule_pairs_train)
# Out:
# 121/121 [==============================] - 6s 18ms/step

# %%
plt.hist(prediction_results_train, bins=10)
# Out:
# (array([1.00e+00, 0.00e+00, 1.00e+00, 1.00e+00, 1.00e+00, 3.00e+00,
#         1.20e+01, 3.20e+01, 1.20e+02, 3.69e+03]),
#  array([0.9681834 , 0.97136509, 0.97454679, 0.97772843, 0.98091012,
#         0.98409182, 0.98727351, 0.99045521, 0.99363685, 0.99681854,
#         1.00000024]),
#  <BarContainer object of 10 artists>)

# %%
# get a uniform distribution of taminoto scores
uniformed_molecule_pairs_test =TrainUtils.uniformise(molecule_pairs_test)

# %%
prediction_results_test = model.predict(uniformed_molecule_pairs_test)
# Out:
# 13/13 [==============================] - 4s 17ms/step

# %%
plt.scatter([m.similarity for m in uniformed_molecule_pairs_train], prediction_results_train, alpha=0.01)
plt.title('Prediction of Taminoto score (TRAIN)')
plt.xlabel('true')
plt.ylabel('pred')
plt.grid()

# %%
plt.plot([m.similarity for m in uniformed_molecule_pairs_test])

# %%
plt.plot(prediction_results_test)

# %%
plt.scatter([m.similarity for m in uniformed_molecule_pairs_test], prediction_results_test, alpha=1)
plt.title('Prediction of Taminoto score (test)')
plt.xlabel('true')
plt.ylabel('pred')
plt.grid()

# %%
r2_score([m.similarity for m in uniformed_molecule_pairs_test], prediction_results_test)
# Out:
# -2.9192837406915015

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_squared_error(new_labels, prediction_results_train)

# %%
mean_squared_error(labels_test_uniform, y_pred)

# %%
plt.hist(labels_test_uniform)

# %%
plt.hist(y_pred)
plt.grid()
plt.title('Histogram predictions')
plt.xlabel('prediction')

# %%
all_spectrums[0].mz

# %%
all_spectrums[0].intensity

# %%
print('Here there is the results of a MS/MS experiment. Tell me the possible molecule')
for intensity, mz in zip(all_spectrums[0].intensity, all_spectrums[0].mz):
    print(f'For m/z: {intensity}, intensity:{mz}')

# %% [markdown]
# ## Debugging

# %%
#new_input_pairs
len(new_labels)

# %% [markdown]
# # equal molecules

# %%
high_molecules= [m for m in uniformed_molecule_pairs_train if m.similarity==1]

# %%
index=11

# %%
for s in [high_molecules[index].spectrum_object_0, high_molecules[index].spectrum_object_1]:
    Plotting.plot_spectrum(s)

# %%
high_molecules[index].params_0
# Out:
# {'pepmass': (89.02, None),
#  'charge': [1],
#  'mslevel': '2',
#  'source_instrument': 'ESI-Orbitrap',
#  'filename': 'BMDMS_mgf.mgf',
#  'seq': '*..*',
#  'ionmode': 'Positive',
#  'organism': 'BMDMS-NP',
#  'name': 'Pyruvic acid [M+H]+',
#  'pi': 'BMDMS-NP',
#  'datacollector': 'BMDMS-NP',
#  'smiles': 'O=C(O)C(=O)C',
#  'inchi': 'InChI=1S/C3H4O3/c1-2(4)3(5)6/h1H3,(H,5,6)',
#  'inchiaux': 'N/A',
#  'pubmed': 'N/A',
#  'submituser': 'mwang87',
#  'libraryquality': '1',
#  'spectrumid': 'CCMSLIB00006372381',
#  'scans': '18081'}

# %%
high_molecules[index].params_1
# Out:
# {'pepmass': (89.02, None),
#  'charge': [1],
#  'mslevel': '2',
#  'source_instrument': 'ESI-Orbitrap',
#  'filename': 'BMDMS_mgf.mgf',
#  'seq': '*..*',
#  'ionmode': 'Positive',
#  'organism': 'BMDMS-NP',
#  'name': 'Pyruvic acid [M+H]+',
#  'pi': 'BMDMS-NP',
#  'datacollector': 'BMDMS-NP',
#  'smiles': 'O=C(O)C(=O)C',
#  'inchi': 'InChI=1S/C3H4O3/c1-2(4)3(5)6/h1H3,(H,5,6)',
#  'inchiaux': 'N/A',
#  'pubmed': 'N/A',
#  'submituser': 'mwang87',
#  'libraryquality': '1',
#  'spectrumid': 'CCMSLIB00006371427',
#  'scans': '17127'}

# %%
Plotting.plot_molecule_pair_spectrum(high_molecules[index])
# Out:
# molecule_0: O=C(O)C(=O)C, molecule_1 = O=C(O)C(=O)C, similarity: 1.0

# %%
CosineDistance.compute_cosine_distance(high_molecules[index].vector_0, high_molecules[index].vector_1)
# Out:
# 0.958281830999467

# %%
plt.hist([CosineDistance.compute_cosine_distance(p.vector_0, p.vector_1) for p in high_molecules])
# Out:
# (array([11.,  6.,  3.,  2.,  2.,  4.,  5.,  6.,  5., 17.]),
#  array([0.        , 0.0994683 , 0.19893659, 0.29840489, 0.39787318,
#         0.49734148, 0.59680977, 0.69627807, 0.79574636, 0.89521466,
#         0.99468295]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Low molecules

# %%
low_molecules= [m for m in uniformed_molecule_pairs_train if m.similarity<0.1]

# %%
index_low=2

# %%
Plotting.plot_molecule_pair_spectrum(low_molecules[index_low])
# Out:
# molecule_0: O=C1OC=2C(OCC(O)C(O)(C)C)=C3OC=CC3=C(OC)C2C=C1, molecule_1 = CCCCCCCCCCCCCCCCCCCCCCCCCCCC, similarity: 0.0392156862745098

# %%
CosineDistance.compute_cosine_distance(low_molecules[index_low].vector_0, low_molecules[index_low].vector_1)
# Out:
# 0.0960597283259173

# %%
plt.hist([CosineDistance.compute_cosine_distance(p.vector_0, p.vector_1) for p in low_molecules])
# Out:
# (array([54.,  7.,  8.,  2.,  3.,  0.,  0.,  0.,  0.,  2.]),
#  array([0.        , 0.05273994, 0.10547987, 0.15821981, 0.21095975,
#         0.26369969, 0.31643962, 0.36917956, 0.4219195 , 0.47465944,
#         0.52739937]),
#  <BarContainer object of 10 artists>)
