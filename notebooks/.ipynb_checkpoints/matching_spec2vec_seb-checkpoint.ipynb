# %%
# %load_ext autoreload
# %autoreload 2

# %%
#!pip install pandas
#!pip install tqdm
#!pip install scipy
#!pip install matchms
#!pip install scikit-learn
#!pip install spec2vec

# %%
import os
os.chdir('/Users/sebas/projects/metabolomics')

# %%
import gensim
from src.load_data import LoadData
from src.config import Config
from matchms import calculate_scores
from matchms.importing import load_from_mgf,load_from_msp
from spec2vec import Spec2Vec
import matchms.filtering as msfilters
from spec2vec import SpectrumDocument
from spec2vec.model_building import train_new_word2vec_model
from tqdm import tqdm

# %%
ls /Users/sebas/projects/data
# Out:
# GNPS-NIH-NATURALPRODUCTSLIBRARY.mgf
# drug_plus.mgf
# hr_msms_nist_sample.MSP
# merged_gnps_nist_20240118_gnps_nist_janssen.pkl
# spec2vec_AllPositive_ratio05_filtered_201101_iter_15.model
# spec2vec_AllPositive_ratio05_filtered_201101_iter_15.model.trainables.syn1neg.npy
# spec2vec_AllPositive_ratio05_filtered_201101_iter_15.model.wv.vectors.npy

# %% [markdown]
# ## Parameters

# %%
data_folder= '/Users/sebas/projects/data/'
dataset_path = data_folder + 'uniformed_test_molecule_pairs.pkl'
gnps_path =  data_folder + 'GNPS-NIH-NATURALPRODUCTSLIBRARY.mgf'
janssen_path = data_folder + 'drug_plus.mgf'
nist_path = data_folder + 'hr_msms_nist_sample.MSP'
output_pairs_file= data_folder + 'molecular_pairs.pkl'
output_nist_file= data_folder + 'all_spectrums_nist.pkl'
output_gnps_file= data_folder + 'all_spectrums_gnps.pkl'
output_janssen_file= data_folder + 'all_spectrums_janssen.pkl'
model_file = data_folder + 'spec2vec_AllPositive_ratio05_filtered_201101_iter_15.model'
uniformed_molecule_pairs_test_path= data_folder +'uniformed_molecule_pairs_test.pkl'
load_molecule_pairs_file= False

# %%
## Load spectrum using spectrumutils

# %%
config=Config()

# %%
spec_su = LoadData.get_all_spectrums(gnps_file, num_samples=10000000, 
                                     compute_classes=False, 
                                     use_tqdm=True, 
                                     use_nist=False, 
                                     config=config, 
                                     use_janssen=False)
# Out:
#   0%|                                                                                                                                                                                                                          | 1254/10000000 [00:01<4:24:42, 629.53it/s]
# We reached the end of the array at index 1254

# %%
## Load spectrum using matchms

# %%
spec_matchms= [(s) for s in load_from_mgf(gnps_file)]

# %%
## check if the hash works

# %%
spec_matchms[26].metadata
# Out:
# {'charge': 1,
#  'ionmode': 'positive',
#  'smiles': 'C[C@@H]1[C@@H]2CC(=O)O[C@@H]3C[C@](C)([C@H]4OC(=O)C=C4C)C(=C(O)C1=O)[C@@]32CO',
#  'scans': '1375',
#  'ms_level': '2',
#  'instrument_type': 'LC-ESI-qTof',
#  'file_name': 'p1-C05_GC5_01_17901.mzXML',
#  'peptide_sequence': '*..*',
#  'organism_name': 'GNPS-NIH-NATURALPRODUCTSLIBRARY',
#  'compound_name': 'MLS000574930-01! M+H',
#  'principal_investigator': 'Dorrestein',
#  'data_collector': 'VVP/LMS',
#  'submit_user': 'vphelan',
#  'confidence': '3',
#  'spectrum_id': 'CCMSLIB00000079376',
#  'precursor_mz': 363.144}

# %%
spec_matchms[26].spectrum_hash()
# Out:
# 'a45ba62f417cf4ca4854'

# %%
spec_su[25].params
# Out:
# {'pepmass': (363.144, None),
#  'charge': [1],
#  'mslevel': '2',
#  'source_instrument': 'LC-ESI-qTof',
#  'filename': 'p1-C05_GC5_01_17901.mzXML',
#  'seq': '*..*',
#  'ionmode': 'Positive',
#  'organism': 'GNPS-NIH-NATURALPRODUCTSLIBRARY',
#  'name': 'MLS000574930-01! M+H',
#  'pi': 'Dorrestein',
#  'datacollector': 'VVP/LMS',
#  'smiles': 'C[C@@H]1[C@@H]2CC(=O)O[C@@H]3C[C@](C)([C@H]4OC(=O)C=C4C)C(=C(O)C1=O)[C@@]32CO',
#  'inchi': 'N/A',
#  'inchiaux': 'N/A',
#  'pubmed': 'N/A',
#  'submituser': 'vphelan',
#  'libraryquality': '3',
#  'spectrumid': 'CCMSLIB00000079376',
#  'scans': '1375'}

# %%
spec_su[25].spectrum_hash
# Out:
# 'a45ba62f417cf4ca4854'

# %%
spectrum_hashes_ms = [s.spectrum_hash() for s in spec_matchms]

# %% [markdown]
# ## Load all the data

# %%
max_number_spectra_gnps=100
max_number_spectra_janssen= 100
max_number_spectra_nist=100
block_size_nist=30000

# %%
loader_saver = LoaderSaver(block_size=block_size_nist, 
                               pickle_nist_path =output_nist_file,
                               pickle_gnps_path =output_gnps_file,
                               pickle_janssen_path=output_janssen_file
                               )

# %%
all_spectrums_janssen = loader_saver.get_all_spectrums(janssen_path,max_number_spectra_janssen, use_tqdm=True, use_nist=False, config=config, use_janssen=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1884.72it/s]

# %%
all_spectrums_gnps = loader_saver.get_all_spectrums(gnps_path,max_number_spectra_gnps, use_tqdm=True, use_nist=False, config=config)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 652.30it/s]

# %%
all_spectrums_nist = loader_saver.get_all_spectrums(nist_path,max_number_spectra_nist, use_tqdm=True, use_nist=True, config=config)
# Out:
# The NIST file contains 34928 lines
# Starting loading spectrums with block size 30000 in the following spectrum index 0 and line number 0
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:27<00:00, 36.24it/s]
# Percentage of N/A smiles in current block: 2.3%
# lenght of spectrums retrievied:352
# Saving spectrums with block size 30000 in the following spectrum index 352 and updated line number 34928
# We got to the end of the NIST file

# %%
len(all_spectrums_gnps), len(all_spectrums_nist), len(all_spectrums_janssen)
# Out:
# (100, 352, 100)

# %%
all_spectrums = all_spectrums_gnps + all_spectrums_nist + all_spectrums_janssen

# %% [markdown]
# ## Compute a set of molecular pairs

# %%
number_pairs=1000

# %%
import dill
from src.load_data import LoadData
from sklearn.model_selection import train_test_split
from src.train_utils import TrainUtils
from src.preprocessor import Preprocessor
import pickle
import sys
from src.config import Config
from src.parser import Parser
from datetime import datetime
from src.loader_saver import LoaderSaver

# %%
if load_molecule_pairs_file:
        with open(uniformed_molecule_pairs_test_path, 'rb') as file:
            dataset = dill.load(file)
        molecule_pairs= dataset['uniformed_molecule_pairs_test']
    else:
        molecule_pairs= TrainUtils.compute_all_tanimoto_results(all_spectrums, 
                                                                max_combinations=number_pairs, 
                                                                use_tqdm=True, 
                                                                max_mass_diff=config.MAX_MASS_DIFF, 
                                                                min_mass_diff=config.MIN_MASS_DIFF)
# Out:
# Starting computation of molecule pairs
# 2024-01-30 16:36:24.441009
# Computing all the tanimoto results
# Processing:   0%|                                                                                                                                                                                                                                | 0/1000 [00:00<?, ?it/s]
# Compute all the fingerprints
# Processing:   0%|▏                                                                                                                                                                                                                       | 1/1000 [00:00<03:59,  4.17it/s]
# Number of workers: 15
# Processing: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 3585.27it/s]
# Number of effective pairs retrieved: 1000
# 2024-01-30 16:36:24.721887

# %%
len(molecule_pairs)
# Out:
# 1000

# %% [markdown]
# ## Load data throguh matchms

# %%
all_spectrums_gnps_MATCHMS = [(s) for s in load_from_mgf(gnps_path)]

# %%
all_spectrums_janssen_MATCHMS = [(s) for s in load_from_mgf(janssen_path)]
# Out:
# 2024-01-30 16:39:01,590:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,592:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,594:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,595:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,595:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,596:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,597:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,598:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,599:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,600:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,601:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,602:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,602:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,603:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,604:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,605:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,607:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,608:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,608:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,610:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,611:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,612:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,614:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,615:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,616:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,617:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,618:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,619:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,620:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,621:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,622:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,623:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,624:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,625:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,626:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,627:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,628:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,628:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,630:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,631:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,632:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,634:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,635:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,635:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,636:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,637:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,639:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,639:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,639:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,640:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,641:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,642:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,642:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,643:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,644:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,645:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,645:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,646:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,647:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,647:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,648:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,650:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,651:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,653:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,654:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,655:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,657:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,658:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,660:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,662:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,664:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,665:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,665:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,667:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,668:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,668:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,669:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,670:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,671:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,672:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,676:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,677:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,678:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,679:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,680:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,680:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,681:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,682:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,683:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,684:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,685:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,687:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,688:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,688:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,688:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,690:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,691:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,691:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,692:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,693:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,694:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,695:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,696:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,697:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,698:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,699:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,700:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,702:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,703:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,704:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,705:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,705:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,707:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,708:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,708:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,710:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,711:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,711:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,712:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,712:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,713:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,714:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,715:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,715:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,716:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,716:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,717:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,718:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,718:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,719:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,719:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,721:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,721:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,723:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,724:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,725:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,725:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,726:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,726:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,727:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,730:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,730:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,732:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,733:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,735:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,736:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,737:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,740:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,741:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,743:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,744:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,745:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,746:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,746:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,747:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,747:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,748:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,749:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,750:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,751:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,754:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,755:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,755:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,756:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,757:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,759:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,760:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,760:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,761:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,763:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,763:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,764:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,765:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,765:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,766:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,766:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,767:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,768:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,769:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,769:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,770:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,770:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,771:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,771:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,771:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,772:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,772:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,773:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,773:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,774:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,775:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,776:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,778:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,778:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,780:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,780:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,781:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,781:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,783:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,783:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,784:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,784:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,786:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,788:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,790:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,791:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,794:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,795:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,798:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,799:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,799:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,800:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,802:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,804:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,805:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,806:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,807:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,808:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,809:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,809:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,810:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,811:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,813:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,813:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,814:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,816:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,817:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,817:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,819:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,819:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,823:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,825:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,827:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,830:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,831:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,832:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,833:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,834:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,835:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,836:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,837:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,838:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,842:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,843:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,843:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,844:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,844:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,845:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,845:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,845:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,846:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,846:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,846:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,847:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,847:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,848:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,848:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,848:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,849:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,849:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,850:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,850:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,851:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,851:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,851:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,852:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,852:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,853:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,853:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,853:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,854:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,854:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,855:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,855:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,856:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,856:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,856:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,857:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,857:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,857:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,858:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,858:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,859:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,859:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,860:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,860:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,860:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,861:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,861:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,861:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,862:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,862:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,863:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,863:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,863:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,864:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,864:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,865:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,865:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,865:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,866:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,866:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,866:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,867:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,867:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,868:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,868:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,869:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,869:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,869:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,870:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,870:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,871:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,871:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,871:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,872:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,872:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,873:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,873:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,873:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,874:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,874:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,875:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,875:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,875:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,876:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,876:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,877:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,877:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,877:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,878:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,878:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,879:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,879:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,879:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,880:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,880:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,881:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,881:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,881:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,882:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,882:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,883:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,883:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,883:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,884:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,884:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,885:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,885:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,885:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,886:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,886:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,886:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,887:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,887:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,888:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,888:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,888:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,889:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,889:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,890:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,890:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,890:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,891:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,891:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,892:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,892:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,892:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,893:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,893:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,894:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,894:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,894:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,895:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,895:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,895:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,896:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,896:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,897:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,897:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,897:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,898:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,898:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,899:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,899:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,899:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,900:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,900:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,901:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,901:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,901:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,902:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,902:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,902:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,903:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,903:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,904:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,904:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,904:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,905:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,905:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,905:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,906:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,906:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,907:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,907:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,907:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,908:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,908:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,909:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,909:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,909:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,910:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,910:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,911:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,911:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,911:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,912:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,912:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,912:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,913:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,913:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,914:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,914:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,914:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,915:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,915:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,915:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,916:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,916:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,917:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,917:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,917:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,918:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,918:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,918:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,919:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,919:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,919:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,920:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,920:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,921:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,921:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,921:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,922:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,922:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,922:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,923:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,923:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,924:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,924:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,924:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,925:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,925:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,926:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,926:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,926:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,927:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,927:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,927:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,928:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,928:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,929:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,929:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,929:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,930:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,930:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,930:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,931:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,931:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,932:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,932:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,933:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,933:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,934:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,934:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,934:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,934:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,935:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,935:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,936:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,936:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,936:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,937:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,937:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,938:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,938:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,938:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,939:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,939:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,940:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,940:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,940:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,941:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,941:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,942:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,942:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,943:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,943:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,943:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,944:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,944:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,945:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,945:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,945:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,946:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,946:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,947:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,947:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,947:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,948:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,948:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,949:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,949:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,949:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,950:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,950:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,950:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,951:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,951:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,952:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,952:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,952:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,953:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,953:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,953:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,954:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,954:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,955:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,955:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,955:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,956:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,956:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,957:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,957:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,957:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,958:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,958:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,958:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,959:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,959:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,959:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,960:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,960:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,961:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,961:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,961:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,962:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,962:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,962:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:01,963:WARNING:matchms:add_retention:N/A can't be converted to float.
# ...
# 2024-01-30 16:39:02,607:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,607:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,608:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,608:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,608:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,609:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,609:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,610:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,610:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,611:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,611:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,611:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,612:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,612:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,612:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,613:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,613:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,614:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,614:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,614:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,615:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,615:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,616:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,616:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,616:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,617:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,617:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,618:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,618:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,618:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,619:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,619:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,620:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,620:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,620:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,621:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,621:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,622:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,622:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,622:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,623:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,623:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,624:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,624:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,624:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,625:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,625:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,626:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,626:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,627:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,627:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,627:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,628:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,628:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,629:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,629:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,629:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,630:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,630:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,631:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,631:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,631:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,632:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,632:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,633:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,633:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,633:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,634:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,634:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,635:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,635:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,635:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,636:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,636:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,637:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,637:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,637:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,638:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,638:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,638:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,639:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,639:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,640:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,640:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,641:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,641:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,641:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,642:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,642:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,643:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,643:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,644:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,644:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,644:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,645:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,645:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,646:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,646:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,647:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,647:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,647:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,648:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,648:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,648:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,649:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,649:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,650:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,650:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,650:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,651:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,651:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,652:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,652:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,652:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,653:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,653:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,653:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,654:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,654:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,655:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,655:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,656:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,656:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,656:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,657:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,657:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,658:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,658:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,659:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,659:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,659:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,660:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,660:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,660:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,661:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,661:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,662:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,662:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,662:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,663:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,663:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,664:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,664:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,664:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,665:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,665:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,666:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,666:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,666:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,667:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,667:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,668:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,668:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,668:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,669:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,669:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,670:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,670:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,670:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,671:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,671:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,672:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,672:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,672:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,673:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,674:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,675:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,676:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,677:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,678:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,679:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,679:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,680:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,680:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,681:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,681:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,682:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,682:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,683:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,683:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,684:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,684:WARNING:matchms:add_retention:N/A can't be converted to float.
# 2024-01-30 16:39:02,685:WARNING:matchms:add_retention:N/A can't be converted to float.

# %%
all_spectrums_nist_MATCHMS = [(s) for s in load_from_msp(nist_path)]

# %%
all_spectrums_MATCHMS = all_spectrums_gnps_MATCHMS + all_spectrums_janssen_MATCHMS + all_spectrums_nist_MATCHMS

# %% [markdown]
# ## Use the molecular pairs to match the spectra in matchms

# %%
hash_gnps_MATCHMS = [s.spectrum_hash() for s in all_spectrums_gnps_MATCHMS]

# %%
hash_janssen_MATCHMS = [s.spectrum_hash() for s in all_spectrums_janssen_MATCHMS]

# %%
hash_nist_MATCHMS = [s.spectrum_hash() for s in all_spectrums_nist_MATCHMS]

# %%
## check that each one of the datasets is in the respective ms foldersm

# %%
is_hash_gnps_su_in_matchms = not(False in [(s.spectrum_hash in hash_gnps_MATCHMS) for s in all_spectrums_gnps])
is_hash_gnps_su_in_matchms
# Out:
# True

# %%
is_hash_janssen_su_in_matchms = not(False in [(s.spectrum_hash in hash_janssen_MATCHMS) for s in all_spectrums_janssen])
is_hash_janssen_su_in_matchms
# Out:
# True

# %%
is_hash_nist_su_in_matchms = not(False in [(s.spectrum_hash in hash_nist_MATCHMS) for s in all_spectrums_nist])
is_hash_nist_su_in_matchms
# Out:
# True

# %%
## sanity check to see that there are no cross appearences

# %% [markdown]
# ## Load spec2vec model

# %%
# Import pre-trained word2vec model (see code example above)
#model_file = "references.model"
model = gensim.models.Word2Vec.load(model_file)

# %%
# Define similarity_function
spec2vec_similarity = Spec2Vec(model=model, intensity_weighting_power=0.5,
                               allowed_missing_percentage=5.0)

# %% [markdown]
# ## compute spec2vec

# %%
def spectrum_processing(s):
    """This is how one would typically design a desired pre- and post-
    processing pipeline."""
    s = msfilters.default_filters(s)
    s = msfilters.add_parent_mass(s)
    s = msfilters.normalize_intensities(s)
    s = msfilters.reduce_to_number_of_peaks(s, n_required=10, ratio_desired=None, n_max=500)
    #s = msfilters.reduce_to_number_of_peaks(s, n_required=10, ratio_desired=0.5, n_max=500)
    s = msfilters.select_by_mz(s, mz_from=0, mz_to=1000)
    s = msfilters.add_losses(s, loss_mz_from=10.0, loss_mz_to=200.0)
    s = msfilters.require_minimum_number_of_peaks(s, n_required=10)
    return s

# %%
molecule_pairs[0:1]

# %%
target_hashes = [s.spectrum_hash() for s in all_spectrums_MATCHMS]

# %%
#preprocess
preprocessed_spectrums = [spectrum_processing(s) for s in all_spectrums_MATCHMS]

# %%
tanimotos= []
scores= []
for m in tqdm(molecule_pairs):
    hash_0 = m.spectrum_object_0.spectrum_hash
    hash_1 = m.spectrum_object_1.spectrum_hash

    # search for right spectra
    spectrum_found_0_ms = [s for s,t in zip(preprocessed_spectrums,target_hashes) if t==hash_0 ][0]
    spectrum_found_1_ms = [s for s,t in zip(preprocessed_spectrums,target_hashes) if t==hash_1 ][0]

    # calculate scores
    if (spectrum_found_0_ms is not None) and (spectrum_found_1_ms is not None):
        score = calculate_scores([spectrum_found_0_ms], [spectrum_found_1_ms], spec2vec_similarity) 
        score = score.scores_by_query(spectrum_found_1_ms, sort=True)[0][1]
        tanimotos.append(m.similarity)
        scores.append(score)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1211.73it/s]

# %%
import matplotlib.pyplot as plt
plt.scatter(tanimotos, scores)
plt.ylabel('pred')
plt.xlabel('truth')
plt.grid()

# %%
from sklearn.metrics import roc_curve, auc
def plot_roc_curve(y_true, y_scores, title='ROC Curve', roc_file_path='./roc_curve.png'):
        """
        Compute and plot the Receiver Operating Characteristic (ROC) curve.
    
        """
        fpr, tpr, thresholds = roc_curve(y_true, y_scores)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(4, 4))
        plt.plot(fpr, tpr, color='r', lw=2, label=f'AUC = {roc_auc:.2f}')
        #plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.0])
        plt.xlabel('False Positive Rate (FPR)')
        plt.ylabel('True Positive Rate (TPR)')
        plt.grid()
        plt.title(title)
        plt.legend(loc='lower right')
        plt.savefig(roc_file_path)

# %%
ground_truth = [1 if t>0.7 else 0 for t in tanimotos]

# %%
import numpy as np
np.sum(ground_truth)
# Out:
# 167

# %%
scores_roc = [s if s>0 else 0 for s in scores ]

# %%
plot_roc_curve(ground_truth, scores_roc)
