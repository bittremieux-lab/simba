# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## Load previous results of tanimoto similarities and simba results
## based on the tanimoto similarities, retrieve the spectra that corresponds to the best candidate for each query
## find if the best candidate is in the 10 first matches

# %%
import os
os.chdir('/Users/sebas/projects/metabolomics')
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

# %%
import dill
from src.preprocessor import Preprocessor
from src.load_data import LoadData
from src.config import Config
from rdkit import Chem
import numpy as np

# %% [markdown]
# ## Parameters

# %%
data_folder= '/Users/sebas/projects/data/'
dataset_path= data_folder +'edit_distance_neurips_nist_exhaustive.pkl'
output_janssen_file= data_folder + 'all_spectrums_janssen.pkl'
casmi_file= data_folder + 'processed_massformer/spec_df.pkl' 
USE_CASMI=True
USE_MCES_RAW=False

# %%
similarities_files= [
#'simba_EDIT_DISTANCE_MCES20_NEURIPS_20241115',
#'simba_EDIT_DISTANCE_MCES20_NEURIPS_precursor_randomized',
    'modified_cosine_casmi_NEURIPS',
    'ms2deepscore_v2_casmi_NEURIPS',
    'simba_generated_data_20250126',
    #'simba_generated_data_20250130',
'spec2vec_casmi_NEURIPS',
                    ]

#model_results_path='simba_EDIT_DISTANCE_MCES20_NEURIPS'
#model_results_path='spec2vec_casmi_NEURIPS'
#model_results_path='ms2deepscore_casmi_NEURIPS'

# %%
tanimoto_results_path = 'tanimoto_similarity_casmi_NEURIPS'

# %%
format_file_unknown = "./notebooks/discovery_search/results/{}_results_analog_discovery_unknwon_compounds.pkl"

# %%
config=Config()

# %% [markdown]
# ## Load reference dataset

# %%
pp=Preprocessor()

# %%
with open(dataset_path, 'rb') as file:
            dataset = dill.load(file)

# %%
all_spectrums_reference_original= dataset['molecule_pairs_train'].spectrums_original +\
                    dataset['molecule_pairs_val'].spectrums_original + \
                        dataset['molecule_pairs_test'].spectrums_original

# %%
import copy
all_spectrums_reference_processed= [copy.deepcopy(s) for s in all_spectrums_reference_original]

# %%
all_spectrums_reference_processed = [pp.preprocess_spectrum(
            s,
            fragment_tol_mass=10,
            fragment_tol_mode="ppm",
            min_intensity=0.01,
            max_num_peaks=100,
            scale_intensity=None,
        ) for s in all_spectrums_reference_processed]
    
all_spectrums_reference = [s_original for s_original, s_processed in zip(all_spectrums_reference_original,all_spectrums_reference_processed) if len(s_processed.mz)>=6]

# %% [markdown]
# ## Load query spectra

# %%
if USE_CASMI:
    all_spectrums_janssen_original=LoadData.get_all_spectrums_casmi(
        casmi_file,
        config=config,
    )
else:
    loader_saver = LoaderSaver(
            block_size=100,
            pickle_nist_path='',
            pickle_gnps_path='',
            pickle_janssen_path=output_janssen_file,
        )
    all_spectrums_janssen_original = loader_saver.get_all_spectrums(
                janssen_path,
                100000000,
                use_tqdm=True,
                use_nist=False,
                config=config,
                use_janssen=True,
            )

# %%
all_spectrums_janssen_processed= [copy.deepcopy(s) for s in all_spectrums_janssen_original]

# %%
pp=Preprocessor()
### remove extra peaks in janssen
all_spectrums_janssen_processed = [pp.preprocess_spectrum(
            s,
            fragment_tol_mass=10,
            fragment_tol_mode="ppm",
            min_intensity=0.01,
            max_num_peaks=100,
            scale_intensity=None,
        ) for s in all_spectrums_janssen_processed]

all_spectrums_janssen = [s_original for s_original, s_processed in zip(all_spectrums_janssen_original,all_spectrums_janssen_processed) if len(s_processed.mz)>=6]

# %% [markdown]
# ## Get only the spectra that is not present

# %%
canon_smiles_reference = [Chem.CanonSmiles(s.smiles) for s in all_spectrums_reference]
canon_smiles_janssen =   [Chem.CanonSmiles(s.smiles) for s in all_spectrums_janssen]
janssen_indexes_in_ref= [i for i,s in enumerate(canon_smiles_janssen) if s in canon_smiles_reference]
janssen_indexes_not_in_ref = [i for i,s in enumerate(canon_smiles_janssen) if s not in canon_smiles_reference]

# %%
len(janssen_indexes_in_ref),len(janssen_indexes_not_in_ref)
# Out:
# (26, 132)

# %%
all_spectrums_janssen = [all_spectrums_janssen[index] for index in janssen_indexes_not_in_ref]

# %% [markdown]
# ## Load similarity results

# %% [markdown]
# ## Load results for simba and spec2vec

# %%
model_results = {}
for sim in similarities_files:
    with open(format_file_unknown.format(sim), 'rb') as f:
                model_results[sim]= dill.load(f)

# %%
with open(format_file_unknown.format(tanimoto_results_path), 'rb') as f:
                tanimoto_results= dill.load(f)

# %%
golden_truth=tanimoto_results['similarities']

# %%
from src.analog_discovery.performance_analysis import PerformanceAnalysis
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
import matplotlib.pyplot as plt

# %%
golden_truth.shape
# Out:
# (132, 328555)

# %%
accuracy_results={}
min_tanimotos= [0, 0.25, 0.5, 0.75, 0.90]
k_list=[10,100, 500, 1000]

#min_tanimotos= [0,0.90]
#k_list=[10,1000]

accuracy_results = {k:{} for k in min_tanimotos}

for sim in model_results:
    
    results_temp = PerformanceAnalysis.obtain_precision_k_candidates(golden_truth=golden_truth, 
                          predicted=model_results[sim]['similarities'], 
                          smiles_reference=model_results[sim]['smiles_reference'],
                           smiles_janssen=model_results[sim]['smiles_janssen'],
                          all_spectrums_reference=all_spectrums_reference, 
                           all_spectrums_janssen=all_spectrums_janssen,
                            min_tanimotos= min_tanimotos,
                            k_list=k_list,)
    for k in min_tanimotos:
        accuracy_results[k][sim] = results_temp[k]
# Out:
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328554)
# Size of predictions: (132, 328554)
# Size of predictions: (132, 328554)
# Size of predictions: (132, 328554)
# Size of predictions: (132, 328554)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328555)
# Size of predictions: (132, 328534)
# Size of predictions: (132, 328534)
# Size of predictions: (132, 328534)
# Size of predictions: (132, 328534)
# Size of predictions: (132, 328534)

# %%
from matplotlib.collections import LineCollection

sim = 'simba_generated_data_20250126'
fig, ax = plt.subplots()
for min_tanimoto in min_tanimotos:
    x= np.array(k_list)
    y=np.array(accuracy_results[min_tanimoto][sim]) 
    
    min_tanimoto_vector = [min_tanimoto for s in y]
    # Prepare the points for the line segments
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    
    
    norm = plt.Normalize(0, 1.0)
    lc = LineCollection(segments, cmap='viridis', norm=norm)
    lc.set_array(min_tanimoto_vector)  # The value determining color
    lc.set_linewidth(2)
    
    # Create the plot
    
    ax.add_collection(lc)
    
    # Add markers at each point
    #ax.plot(x, y, '*', color='black', markersize=5)  # Adds '*' markers
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(y.min(), y.max())

    # Annotate the line with its min_tanimoto value near the last point
    # Add a proxy line for the legend
    ax.plot([], [], label=f'Min Tanimoto = {min_tanimoto}', color=plt.cm.viridis(norm(min_tanimoto)))
    
#plt.colorbar(lc, ax=ax, label='min tanimoto')
plt.ylim([0,0.8])
plt.grid()
plt.xlabel('k candidates')
plt.ylabel('accuracy')
plt.legend(loc='lower right')

# %%
import matplotlib.pyplot as plt
colors=['b','k','r', 'g']

min_tanimoto=0.00
#plt.figure(figsize=(10,5))
for sim,c in zip(similarities_files, colors):
        plt.plot(k_list, accuracy_results[min_tanimoto][sim], marker="*", color=c, label=sim)


plt.xlabel('k candidates')
#plt.ylim([0.00,0.42])
plt.ylim([0.00,0.42])
#plt.xscale('log')
plt.legend(loc= "lower right")
plt.ylabel('accuracy')
plt.grid()

# %% [markdown]
# ## Let's compare predictions for simba and spec2vec

# %%
target_indexes_list=np.arange(0,len(all_spectrums_janssen))
K=10

# %%
from rdkit.Chem import Draw
import matplotlib.pyplot as plt
from src.tanimoto import Tanimoto
from src.mces.mces_computation import MCES

# %%
from src.analog_discovery.performance_analysis import PerformanceAnalysis

# %%
folder_path = data_folder + "comparison_simba_spec2vec_precursor_randomized/"

# %%
PerformanceAnalysis.plot_performance(model_results, 
                                    target_indexes_list,
                                    all_spectrums_janssen, 
                                    all_spectrums_reference,
                                    K,
                                    golden_truth,
                                    folder_path)
# Out:
# Running myopic ...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/ec716fca99d24d6f9361fe21045748cf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/ec716fca99d24d6f9361fe21045748cf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5504 COLUMNS
# At line 31199 RHS
# At line 36699 BOUNDS
# At line 39677 ENDATA
# Problem MODEL has 5499 rows, 2977 columns and 18972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.30 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3049 rows, 2948 columns (2948 integer (2948 of which binary)) and 16603 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.77636e-15
# Cbc0038I Solution found of 6
# Cbc0038I Before mini branch and bound, 2948 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.10 seconds)
# Cbc0038I After 1.10 seconds - Feasibility pump exiting with objective of 6 - took 0.01 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (1.10 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (1.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.16
# Time (Wallclock seconds):       1.19
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.17   (Wallclock seconds):       1.21
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/993dd55a33414d1da1761bbff8f922b2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/993dd55a33414d1da1761bbff8f922b2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6636 COLUMNS
# At line 37344 RHS
# At line 43976 BOUNDS
# At line 47537 ENDATA
# Problem MODEL has 6631 rows, 3560 columns and 22704 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 13 - 0.54 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3647 rows, 3530 columns (3530 integer (3530 of which binary)) and 19794 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 13
# Cbc0038I Before mini branch and bound, 3530 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.93 seconds)
# Cbc0038I After 1.93 seconds - Feasibility pump exiting with objective of 13 - took 0.01 seconds
# Cbc0012I Integer solution of 13 found by feasibility pump after 0 iterations and 0 nodes (1.93 seconds)
# Cbc0001I Search completed - best objective 13, took 0 iterations and 0 nodes (1.93 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 13 to 13
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             2.06
# Time (Wallclock seconds):       2.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.08   (Wallclock seconds):       2.09
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/79f6fb40ab434b01b58ac1dadec61e09-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/79f6fb40ab434b01b58ac1dadec61e09-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5504 COLUMNS
# At line 31199 RHS
# At line 36699 BOUNDS
# At line 39677 ENDATA
# Problem MODEL has 5499 rows, 2977 columns and 18972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.31 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3049 rows, 2948 columns (2948 integer (2948 of which binary)) and 16603 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 8.26006e-14
# Cbc0038I Solution found of 6
# Cbc0038I Before mini branch and bound, 2948 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.05 seconds)
# Cbc0038I After 1.05 seconds - Feasibility pump exiting with objective of 6 - took 0.00 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (1.05 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (1.05 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.13
# Time (Wallclock seconds):       1.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.14   (Wallclock seconds):       1.15
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/3eec97a335d547688939a4ac14b85e8c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/3eec97a335d547688939a4ac14b85e8c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5504 COLUMNS
# At line 31199 RHS
# At line 36699 BOUNDS
# At line 39677 ENDATA
# Problem MODEL has 5499 rows, 2977 columns and 18972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.30 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3049 rows, 2948 columns (2948 integer (2948 of which binary)) and 16603 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.77636e-15
# Cbc0038I Solution found of 6
# Cbc0038I Before mini branch and bound, 2948 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.08 seconds)
# Cbc0038I After 1.08 seconds - Feasibility pump exiting with objective of 6 - took 0.00 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (1.08 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (1.08 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.15
# Time (Wallclock seconds):       1.17
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.17   (Wallclock seconds):       1.18
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/fdb70e5f94e04e1ea60c5bf20bbd0f34-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/fdb70e5f94e04e1ea60c5bf20bbd0f34-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6744 COLUMNS
# At line 37787 RHS
# At line 44527 BOUNDS
# At line 48128 ENDATA
# Problem MODEL has 6739 rows, 3600 columns and 22954 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 14 - 0.51 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 273 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 273 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3685 rows, 3571 columns (3571 integer (3571 of which binary)) and 19962 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.99507e-13
# Cbc0038I Solution found of 14
# Cbc0038I Before mini branch and bound, 3571 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.10 seconds)
# Cbc0038I After 2.10 seconds - Feasibility pump exiting with objective of 14 - took 0.01 seconds
# Cbc0012I Integer solution of 14 found by feasibility pump after 0 iterations and 0 nodes (2.10 seconds)
# Cbc0001I Search completed - best objective 14, took 0 iterations and 0 nodes (2.11 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 14 to 14
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                14.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             2.27
# Time (Wallclock seconds):       2.28
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.28   (Wallclock seconds):       2.30
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/7e0514eb7d744768bc91f8ad86baeec5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/7e0514eb7d744768bc91f8ad86baeec5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5504 COLUMNS
# At line 31199 RHS
# At line 36699 BOUNDS
# At line 39677 ENDATA
# Problem MODEL has 5499 rows, 2977 columns and 18972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.31 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3049 rows, 2948 columns (2948 integer (2948 of which binary)) and 16603 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 8.26006e-14
# Cbc0038I Solution found of 6
# Cbc0038I Before mini branch and bound, 2948 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.04 seconds)
# Cbc0038I After 1.04 seconds - Feasibility pump exiting with objective of 6 - took 0.00 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (1.04 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (1.05 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.12
# Time (Wallclock seconds):       1.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.13   (Wallclock seconds):       1.14
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/197e7c5534f740f28fa9c639381ced9d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/197e7c5534f740f28fa9c639381ced9d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5504 COLUMNS
# At line 31199 RHS
# At line 36699 BOUNDS
# At line 39677 ENDATA
# Problem MODEL has 5499 rows, 2977 columns and 18972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6 - 0.31 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3049 rows, 2948 columns (2948 integer (2948 of which binary)) and 16603 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.77636e-15
# Cbc0038I Solution found of 6
# Cbc0038I Before mini branch and bound, 2948 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.10 seconds)
# Cbc0038I After 1.10 seconds - Feasibility pump exiting with objective of 6 - took 0.01 seconds
# Cbc0012I Integer solution of 6 found by feasibility pump after 0 iterations and 0 nodes (1.10 seconds)
# Cbc0001I Search completed - best objective 6, took 0 iterations and 0 nodes (1.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6 to 6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.17
# Time (Wallclock seconds):       1.19
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.19   (Wallclock seconds):       1.20
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/c67afb8016174fedb075f2c943d5267b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/c67afb8016174fedb075f2c943d5267b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6528 COLUMNS
# At line 36646 RHS
# At line 43170 BOUNDS
# At line 46663 ENDATA
# Problem MODEL has 6523 rows, 3492 columns and 22267 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12 - 0.47 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3579 rows, 3463 columns (3463 integer (3463 of which binary)) and 19384 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.34781e-13
# Cbc0038I Solution found of 12
# Cbc0038I Before mini branch and bound, 3463 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.97 seconds)
# Cbc0038I After 1.97 seconds - Feasibility pump exiting with objective of 12 - took 0.01 seconds
# Cbc0012I Integer solution of 12 found by feasibility pump after 0 iterations and 0 nodes (1.98 seconds)
# Cbc0001I Search completed - best objective 12, took 0 iterations and 0 nodes (1.98 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 12 to 12
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             2.12
# Time (Wallclock seconds):       2.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.14   (Wallclock seconds):       2.15
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/e969e13e7bad4939ac9da7e65a7d4f93-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/e969e13e7bad4939ac9da7e65a7d4f93-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6636 COLUMNS
# At line 37344 RHS
# At line 43976 BOUNDS
# At line 47537 ENDATA
# Problem MODEL has 6631 rows, 3560 columns and 22704 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 13 - 0.54 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 263 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3647 rows, 3530 columns (3530 integer (3530 of which binary)) and 19794 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 13
# Cbc0038I Before mini branch and bound, 3530 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.95 seconds)
# Cbc0038I After 1.95 seconds - Feasibility pump exiting with objective of 13 - took 0.01 seconds
# Cbc0012I Integer solution of 13 found by feasibility pump after 0 iterations and 0 nodes (1.95 seconds)
# Cbc0001I Search completed - best objective 13, took 0 iterations and 0 nodes (1.96 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 13 to 13
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             2.09
# Time (Wallclock seconds):       2.11
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.10   (Wallclock seconds):       2.12
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/588a3b87835e4f98b52fb0314d4f3220-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/588a3b87835e4f98b52fb0314d4f3220-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 4264 COLUMNS
# At line 24611 RHS
# At line 28871 BOUNDS
# At line 31226 ENDATA
# Problem MODEL has 4259 rows, 2354 columns and 14990 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 131 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 131 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2413 rows, 2325 columns (2325 integer (2325 of which binary)) and 13244 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 16
# Cbc0038I Before mini branch and bound, 2325 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.15 seconds)
# Cbc0038I After 0.15 seconds - Feasibility pump exiting with objective of 16 - took 0.00 seconds
# Cbc0012I Integer solution of 16 found by feasibility pump after 0 iterations and 0 nodes (0.15 seconds)
# Cbc0001I Search completed - best objective 16, took 0 iterations and 0 nodes (0.15 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 16 to 16
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                16.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.15
# Time (Wallclock seconds):       0.15
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.16   (Wallclock seconds):       0.16
#
# Finished myopic
# reading csv
# Running myopic ...
# Finished myopic
# reading csv
# Running myopic ...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/1e3ed1ccccd84dedae7e0b718731f0a2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/1e3ed1ccccd84dedae7e0b718731f0a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5612 COLUMNS
# At line 30906 RHS
# At line 36514 BOUNDS
# At line 39458 ENDATA
# Problem MODEL has 5607 rows, 2943 columns and 18680 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 17 - 0.65 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2998 rows, 2905 columns (2905 integer (2905 of which binary)) and 15976 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.77316e-14
# Cbc0038I Solution found of 17
# Cbc0038I Before mini branch and bound, 2905 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.71 seconds)
# Cbc0038I After 1.71 seconds - Feasibility pump exiting with objective of 17 - took 0.01 seconds
# Cbc0012I Integer solution of 17 found by feasibility pump after 0 iterations and 0 nodes (1.71 seconds)
# Cbc0001I Search completed - best objective 17, took 0 iterations and 0 nodes (1.72 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 17 to 17
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                17.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.86
# Time (Wallclock seconds):       1.87
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.87   (Wallclock seconds):       1.88
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/1dd2bf62435c4afcb9266cbccefdb43b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/1dd2bf62435c4afcb9266cbccefdb43b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5612 COLUMNS
# At line 30906 RHS
# At line 36514 BOUNDS
# At line 39458 ENDATA
# Problem MODEL has 5607 rows, 2943 columns and 18680 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 17 - 0.66 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2998 rows, 2905 columns (2905 integer (2905 of which binary)) and 15976 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.77316e-14
# Cbc0038I Solution found of 17
# Cbc0038I Before mini branch and bound, 2905 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.73 seconds)
# Cbc0038I After 1.73 seconds - Feasibility pump exiting with objective of 17 - took 0.01 seconds
# Cbc0012I Integer solution of 17 found by feasibility pump after 0 iterations and 0 nodes (1.73 seconds)
# Cbc0001I Search completed - best objective 17, took 0 iterations and 0 nodes (1.73 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 17 to 17
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                17.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.87
# Time (Wallclock seconds):       1.89
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.88   (Wallclock seconds):       1.90
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/870d84d474b244249527d44a7957b181-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/870d84d474b244249527d44a7957b181-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5612 COLUMNS
# At line 30906 RHS
# At line 36514 BOUNDS
# At line 39458 ENDATA
# Problem MODEL has 5607 rows, 2943 columns and 18680 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 17 - 0.67 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 253 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2998 rows, 2905 columns (2905 integer (2905 of which binary)) and 15976 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 5.77316e-14
# Cbc0038I Solution found of 17
# Cbc0038I Before mini branch and bound, 2905 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.74 seconds)
# Cbc0038I After 1.74 seconds - Feasibility pump exiting with objective of 17 - took 0.01 seconds
# Cbc0012I Integer solution of 17 found by feasibility pump after 0 iterations and 0 nodes (1.74 seconds)
# Cbc0001I Search completed - best objective 17, took 0 iterations and 0 nodes (1.74 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 17 to 17
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                17.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.89
# Time (Wallclock seconds):       1.90
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.90   (Wallclock seconds):       1.91
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/730d400c7d64436eb538686326e4d529-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/730d400c7d64436eb538686326e4d529-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5772 COLUMNS
# At line 32026 RHS
# At line 37794 BOUNDS
# At line 40848 ENDATA
# Problem MODEL has 5767 rows, 3053 columns and 19428 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 18.5189 - 1.09 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 248 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 248 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3158 rows, 3043 columns (3043 integer (3043 of which binary)) and 16907 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 312 integers unsatisfied sum - 49.827
# Cbc0038I Pass   1: (5.18 seconds) suminf.   13.04167 (64) obj. 20 iterations 4560
# Cbc0038I Pass   2: (5.51 seconds) suminf.    7.87500 (49) obj. 20 iterations 2289
# Cbc0038I Pass   3: (5.66 seconds) suminf.    7.33333 (61) obj. 20 iterations 1006
# Cbc0038I Pass   4: (5.73 seconds) suminf.    7.14286 (72) obj. 20 iterations 464
# Cbc0038I Pass   5: (5.97 seconds) suminf.   11.34375 (57) obj. 20 iterations 1644
# Cbc0038I Pass   6: (6.12 seconds) suminf.    8.51974 (62) obj. 20 iterations 1083
# Cbc0038I Pass   7: (6.19 seconds) suminf.    8.16463 (48) obj. 20 iterations 484
# Cbc0038I Pass   8: (6.33 seconds) suminf.    8.58333 (48) obj. 20 iterations 950
# Cbc0038I Pass   9: (6.43 seconds) suminf.    6.98333 (76) obj. 20 iterations 660
# Cbc0038I Pass  10: (6.46 seconds) suminf.    6.95968 (78) obj. 20 iterations 125
# Cbc0038I Pass  11: (6.75 seconds) suminf.    8.78571 (48) obj. 20 iterations 2104
# Cbc0038I Pass  12: (6.90 seconds) suminf.    6.66667 (51) obj. 20 iterations 1087
# Cbc0038I Pass  13: (6.98 seconds) suminf.    5.51562 (61) obj. 20 iterations 500
# Cbc0038I Pass  14: (7.00 seconds) suminf.    5.51563 (61) obj. 20 iterations 127
# Cbc0038I Pass  15: (7.13 seconds) suminf.    5.07692 (52) obj. 20 iterations 935
# Cbc0038I Pass  16: (7.24 seconds) suminf.    5.07500 (62) obj. 20 iterations 756
# Cbc0038I Pass  17: (7.41 seconds) suminf.   10.00000 (32) obj. 20 iterations 1232
# Cbc0038I Pass  18: (7.53 seconds) suminf.    6.62500 (39) obj. 20 iterations 846
# Cbc0038I Pass  19: (7.67 seconds) suminf.    6.46429 (40) obj. 20 iterations 958
# Cbc0038I Pass  20: (7.70 seconds) suminf.    6.29545 (58) obj. 20 iterations 221
# Cbc0038I Pass  21: (7.75 seconds) suminf.    6.28571 (58) obj. 20 iterations 306
# Cbc0038I Pass  22: (7.94 seconds) suminf.    5.75000 (37) obj. 20 iterations 1413
# Cbc0038I Pass  23: (8.11 seconds) suminf.    5.75000 (37) obj. 20 iterations 1198
# Cbc0038I Pass  24: (8.32 seconds) suminf.    6.00000 (29) obj. 20 iterations 1410
# Cbc0038I Pass  25: (8.43 seconds) suminf.    5.60294 (62) obj. 20 iterations 758
# Cbc0038I Pass  26: (8.60 seconds) suminf.    6.25000 (30) obj. 20 iterations 1125
# Cbc0038I Pass  27: (8.74 seconds) suminf.    6.11413 (72) obj. 20 iterations 1004
# Cbc0038I Pass  28: (8.89 seconds) suminf.    6.25000 (31) obj. 20 iterations 1084
# Cbc0038I Pass  29: (9.03 seconds) suminf.    5.75000 (37) obj. 20 iterations 901
# Cbc0038I Pass  30: (9.23 seconds) suminf.    6.00000 (29) obj. 20 iterations 1329
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2696 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 3158 rows 3043 columns, reduced to 425 rows 338 columns
# Cbc0038I Mini branch and bound did not improve solution (9.32 seconds)
# Cbc0038I Full problem 3159 rows 3043 columns, reduced to 3159 rows 3043 columns - too large
# Cbc0038I After 9.95 seconds - Feasibility pump exiting - took 5.34 seconds
# Cbc0013I At root node, 0 cuts changed objective from 18.518868 to 18.518868 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 18.518868 (10.88 seconds)
# Cbc0001I Search completed - best objective 1e+50, took 33759 iterations and 46 nodes (29.34 seconds)
# Cbc0032I Strong branching done 540 times (43770 iterations), fathomed 1 nodes and fixed 3 variables
# Cbc0035I Maximum depth 10, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 18.5189 to 18.5189
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               46
# Total iterations:               33759
# Time (CPU seconds):             29.24
# Time (Wallclock seconds):       29.34
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       29.25   (Wallclock seconds):       29.36
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/8f92a052c59c45f1aae3637917aa47db-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/8f92a052c59c45f1aae3637917aa47db-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5396 COLUMNS
# At line 29591 RHS
# At line 34983 BOUNDS
# At line 37800 ENDATA
# Problem MODEL has 5391 rows, 2816 columns and 17874 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16 - 0.43 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 237 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 237 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2866 rows, 2780 columns (2780 integer (2780 of which binary)) and 15249 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 16
# Cbc0038I Before mini branch and bound, 2780 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (1.41 seconds)
# Cbc0038I After 1.41 seconds - Feasibility pump exiting with objective of 16 - took 0.00 seconds
# Cbc0012I Integer solution of 16 found by feasibility pump after 0 iterations and 0 nodes (1.41 seconds)
# Cbc0001I Search completed - best objective 16, took 0 iterations and 0 nodes (1.41 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 16 to 16
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ...
# Cbc0038I Pass  31: suminf.   24.36392 (285) obj. 10.9448 iterations 123
# Cbc0038I Pass  32: suminf.   24.13797 (304) obj. 10.9448 iterations 66
# Cbc0038I Pass  33: suminf.   24.27516 (299) obj. 10.9448 iterations 34
# Cbc0038I Pass  34: suminf.   25.46800 (294) obj. 10.9448 iterations 67
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 160 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 586 rows 554 columns, reduced to 486 rows 393 columns - 32 fixed gives 39, 32 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.26 seconds)
# Cbc0038I After 0.26 seconds - Feasibility pump exiting with objective of 12 - took 0.20 seconds
# Cbc0012I Integer solution of 12 found by feasibility pump after 0 iterations and 0 nodes (0.27 seconds)
# Cbc0038I Full problem 586 rows 554 columns, reduced to 427 rows 332 columns - 32 fixed gives 37, 30 - ok now
# Cbc0031I 21 added rows had average density of 92.52381
# Cbc0013I At root node, 63 cuts changed objective from 10.723445 to 11.001632 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 15 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 39 row cuts average 305.9 elements, 0 column cuts (0 active)  in 0.049 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 9 row cuts average 15.2 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 12, took 0 iterations and 0 nodes (0.38 seconds)
# Cbc0035I Maximum depth 0, 106 variables fixed on reduced cost
# Cuts at root node changed objective from 10.7234 to 11.0016
# Probing was tried 1 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# ZeroHalf was tried 1 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.38
# Time (Wallclock seconds):       0.39
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.38   (Wallclock seconds):       0.39
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/7ad0badd8b5a4f39a4f899e6eecc32ed-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/4x/y1dnj1n55js4gtv69lsx4g4h0000gn/T/7ad0badd8b5a4f39a4f899e6eecc32ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 802 COLUMNS
# At line 5399 RHS
# At line 6197 BOUNDS
# At line 6756 ENDATA
# Problem MODEL has 797 rows, 558 columns and 3404 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.52192 - 0.05 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0004I processed model has 590 rows, 558 columns (558 integer (558 of which binary)) and 3276 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 323 integers unsatisfied sum - 26.74
# Cbc0038I Pass   1: suminf.   16.85039 (105) obj. 11.2441 iterations 755
# Cbc0038I Pass   2: suminf.   13.09667 (98) obj. 14.42 iterations 247
# Cbc0038I Pass   3: suminf.   10.20000 (69) obj. 17.12 iterations 195
# Cbc0038I Pass   4: suminf.    7.55000 (47) obj. 19.5 iterations 89
# Cbc0038I Pass   5: suminf.    6.00000 (25) obj. 20 iterations 320
# Cbc0038I Pass   6: suminf.    6.00000 (25) obj. 20 iterations 121
# Cbc0038I Pass   7: suminf.    0.00000 (0) obj. 20 iterations 118
# Cbc0038I Solution found of 20
# Cbc0038I Before mini branch and bound, 219 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 590 rows 558 columns, reduced to 423 rows 336 columns - 12 fixed gives 127, 99 - ok now
# Cbc0038I Full problem 590 rows 558 columns, reduced to 124 rows 97 columns
# Cbc0038I Mini branch and bound improved solution from 20 to 16 (0.16 seconds)
# Cbc0038I Round again with cutoff of 14.2523
# Cbc0038I Pass   8: suminf.   16.85039 (105) obj. 11.2441 iterations 0
# Cbc0038I Pass   9: suminf.   13.22089 (98) obj. 14.2523 iterations 334
# Cbc0038I Pass  10: suminf.   12.73109 (80) obj. 14.2523 iterations 242
# Cbc0038I Pass  11: suminf.    1.26141 (20) obj. 14.2523 iterations 401
# Cbc0038I Solution found of 14
# Cbc0038I Before mini branch and bound, 219 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 590 rows 558 columns, reduced to 423 rows 336 columns - 27 fixed gives 133, 117 - ok now
# Cbc0038I Full problem 590 rows 558 columns, reduced to 133 rows 117 columns
# Cbc0038I Mini branch and bound improved solution from 14 to 12 (0.22 seconds)
# Cbc0038I Round again with cutoff of 10.3045
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 3
# Cbc0038I Pass  12: suminf.   17.36150 (112) obj. 10.3045 iterations 97
# Cbc0038I Pass  13: suminf.   16.10583 (118) obj. 10.3045 iterations 280
# Cbc0038I Pass  14: suminf.   15.78933 (116) obj. 10.3045 iterations 167
# Cbc0038I Pass  15: suminf.   13.89843 (84) obj. 10.3045 iterations 415
# Cbc0038I Pass  16: suminf.   11.81208 (112) obj. 10.3045 iterations 371
# Cbc0038I Pass  17: suminf.    1.82678 (12) obj. 10.3045 iterations 397
# Cbc0038I Solution found of 10
# Cbc0038I Before mini branch and bound, 215 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 590 rows 558 columns, reduced to 424 rows 340 columns - 24 fixed gives 162, 143 - ok now
# Cbc0038I Full problem 590 rows 558 columns, reduced to 162 rows 143 columns
# Cbc0038I Mini branch and bound did not improve solution (0.32 seconds)
# Cbc0038I Round again with cutoff of 8.55664
# Cbc0038I Reduced cost fixing fixed 25 variables on major pass 4
# Cbc0038I Pass  18: suminf.   18.38637 (110) obj. 8.55664 iterations 271
# Cbc0038I Pass  19: suminf.   18.14947 (123) obj. 8.55664 iterations 184
# Cbc0038I Pass  20: suminf.   19.17938 (131) obj. 8.55664 iterations 508
# Cbc0038I Pass  21: suminf.   17.41642 (120) obj. 8.55664 iterations 189
# Cbc0038I Pass  22: suminf.   17.22314 (130) obj. 8.55664 iterations 199
# Cbc0038I Pass  23: suminf.   17.10923 (121) obj. 8.55664 iterations 69
# Cbc0038I Pass  24: suminf.   17.01553 (142) obj. 8.55664 iterations 108
# Cbc0038I Pass  25: suminf.   15.47329 (198) obj. 8.55664 iterations 369
# Cbc0038I Pass  26: suminf.   14.89711 (226) obj. 8.55664 iterations 187
# Cbc0038I Pass  27: suminf.   15.09580 (186) obj. 8.55664 iterations 176
# Cbc0038I Pass  28: suminf.   14.73690 (222) obj. 8.55664 iterations 159
# Cbc0038I Pass  29: suminf.   14.72309 (199) obj. 8.55664 iterations 88
# Cbc0038I Pass  30: suminf.   14.57101 (223) obj. 8.55664 iterations 85
# Cbc0038I Pass  31: suminf.   15.33050 (225) obj. 8.55664 iterations 234
# Cbc0038I Pass  32: suminf.   14.89711 (226) obj. 8.55664 iterations 134
# Cbc0038I Pass  33: suminf.   14.65662 (222) obj. 8.55664 iterations 134
# Cbc0038I Pass  34: suminf.   19.28475 (149) obj. 8.55664 iterations 278
# Cbc0038I Pass  35: suminf.   15.60698 (209) obj. 8.55664 iterations 305
# Cbc0038I Pass  36: suminf.   14.57101 (223) obj. 8.55664 iterations 138
# Cbc0038I Pass  37: suminf.   14.80238 (235) obj. 8.55664 iterations 131
# Cbc0038I Pass  38: suminf.   14.73690 (222) obj. 8.55664 iterations 82
# Cbc0038I Pass  39: suminf.   14.72309 (199) obj. 8.55664 iterations 111
# Cbc0038I Pass  40: suminf.   18.01607 (138) obj. 8.55664 iterations 326
# Cbc0038I Pass  41: suminf.   20.57172 (124) obj. 8.55664 iterations 422
# Cbc0038I Pass  42: suminf.   14.72282 (199) obj. 8.55664 iterations 463
# Cbc0038I Pass  43: suminf.   14.57101 (223) obj. 8.55664 iterations 109
# Cbc0038I Pass  44: suminf.   15.11096 (209) obj. 8.55664 iterations 246
# Cbc0038I Pass  45: suminf.   14.89711 (226) obj. 8.55664 iterations 104
# Cbc0038I Pass  46: suminf.   15.06302 (191) obj. 8.55664 iterations 142
# Cbc0038I Pass  47: suminf.   14.73690 (222) obj. 8.55664 iterations 114
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 187 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 590 rows 558 columns, reduced to 442 rows 367 columns - 24 fixed gives 162, 143 - ok now
# Cbc0038I Full problem 590 rows 558 columns, reduced to 146 rows 115 columns
# Cbc0038I Mini branch and bound did not improve solution (0.57 seconds)
# Cbc0038I After 0.57 seconds - Feasibility pump exiting with objective of 10 - took 0.48 seconds
# Cbc0012I Integer solution of 10 found by feasibility pump after 0 iterations and 0 nodes (0.57 seconds)
# Cbc0038I Full problem 590 rows 558 columns, reduced to 418 rows 321 columns - 24 fixed gives 155, 125 - ok now
# Cbc0038I Full problem 590 rows 558 columns, reduced to 144 rows 112 columns
# Cbc0031I 14 added rows had average density of 367.07143
# Cbc0013I At root node, 14 cuts changed objective from 7.5219164 to 7.9790562 in 8 passes
# Cbc0014I Cut generator 0 (Probing) - 16 row cuts average 3.9 elements, 1 column cuts (1 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 79 row cuts average 449.6 elements, 0 column cuts (0 active)  in 0.203 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 10 best solution, best possible 7.9790562 (1.59 seconds)
# Cbc0027I Exiting on user event
# Cbc0005I Partial search - best objective 10 (best possible 7.9790562), took 1677 iterations and 1 nodes (1.75 seconds)
# Cbc0032I Strong branching done 222 times (19483 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 1, 26 variables fixed on reduced cost
# Cuts at root node changed objective from 7.52192 to 7.97906
# Probing was tried 9 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Gomory was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# Knapsack was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# FlowCover was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 8 times and created 79 cuts of which 0 were active after adding rounds of cuts (0.203 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
#
# Result - User ctrl-cuser ctrl-c
#
# Objective value:                10.00000000
# Lower bound:                    7.979
# Gap:                            0.25
# Enumerated nodes:               1
# Total iterations:               1677
# Time (CPU seconds):             1.74
# Time (Wallclock seconds):       1.76
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.74   (Wallclock seconds):       1.77
# Traceback (most recent call last):
#   File "/Users/sebas/miniconda3/envs/transformers/bin/myopic_mces", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/myopic_mces/myopic_mces.py", line 125, in main
#     results = [MCES(i[0], i[1], i[2], threshold, solver, **additional_mces_options) for i in inputs]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/myopic_mces/myopic_mces.py", line 125, in <listcomp>
#     results = [MCES(i[0], i[1], i[2], threshold, solver, **additional_mces_options) for i in inputs]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/myopic_mces/myopic_mces.py", line 71, in MCES
#     res = MCES_ILP(G1, G2, threshold, solver, solver_options=solver_options, no_ilp_threshold=no_ilp_threshold)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/myopic_mces/MCES_ILP.py", line 154, in MCES_ILP
#     ILP.solve()
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/pulp.py", line 1883, in solve
#     status = solver.actualSolve(self, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/apis/coin_api.py", line 112, in actualSolve
#     return self.solve_CBC(lp, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/site-packages/pulp/apis/coin_api.py", line 178, in solve_CBC
#     if cbc.wait() != 0:
#        ^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/subprocess.py", line 2046, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/Users/sebas/miniconda3/envs/transformers/lib/python3.11/subprocess.py", line 2004, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x157c2ad40> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x2f551cd60> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %% [markdown]
# ## for a specific query show the candidates

# %%
target_index=2

# %%
simba_similarities=model_results[[s for s in model_results.keys() if s.startswith('simba')][0]]['similarities']

# %%
target_query=all_spectrums_janssen[target_index]

# %%
smiles_query= target_query.params['smiles']

# %%
Chem.MolFromSmiles(smiles_query)

# %%
## What is the best match based on tanimoto?
best_golden_truth_index=np.argsort(golden_truth[target_index])[::-1][0]

# %%
Chem.MolFromSmiles(all_spectrums_reference[best_golden_truth_index].params['smiles'])

# %%
import spectrum_utils.plot as sup
sup.mirror(target_query, all_spectrums_reference[best_golden_truth_index], )

# %%
print(f'The normalized MCES prediction of SIMBA for the golden truth is {simba_similarities[target_index, best_golden_truth_index]}')

# %%
print(f'The MCES prediction of SIMBA for the golden truth is {40-(40*simba_similarities[target_index, best_golden_truth_index])}')

# %%
## the best golden truth is ranked
np.where(np.argsort(simba_similarities[target_index])[::-1] == best_golden_truth_index)[0]

# %%
rank=8
highest_prediction_index=np.argsort(simba_similarities[target_index])[::-1][rank]

# %%
Chem.MolFromSmiles(all_spectrums_reference[highest_prediction_index].params['smiles'])

# %%
all_spectrums_reference[highest_prediction_index].mz

# %%
(all_spectrums_reference[highest_prediction_index].intensity)

# %%
## there is a peak disappearing after 300 for the query
#preprocess the spectrum and lets see how it looks like
import copy
target_query_copy= copy.deepcopy(target_query)
ref_copy= copy.deepcopy(all_spectrums_reference[highest_prediction_index])
pp=Preprocessor()
target_query_copy=pp.preprocess_spectrum(spectrum=target_query_copy)
ref_copy=pp.preprocess_spectrum(spectrum=ref_copy)
sup.mirror(target_query_copy, ref_copy, )

# %%
np.sort(golden_truth[0]).shape

# %%
#supall_spectrums_reference[best_golden_truth_index]

# %%
#dict_temp['similarities']

# %%
target_similarities= dict_temp['similarities'][target_index]
indexes_k_retrieved=np.argsort(target_similarities)[::-1][0:10]

# %%
indexes_k_retrieved

# %%
smiles_retrieved=  [all_spectrums_reference[index].params['smiles'] for index in indexes_k_retrieved]
sim_k_retrieved=     np.sort(target_similarities)[::-1][0:10]

# %%
### Plotting examples 

for (smile,sim,) in (zip(smiles_retrieved,sim_k_retrieved,)):

    
    mol = Chem.MolFromSmiles(smile)
    tanimoto= Tanimoto.compute_tanimoto_from_smiles(smile, smiles_query)

    
    mces_pred = sim
    if mol:
        img = Draw.MolToImage(mol, size=(200, 200))
        plt.figure()
        plt.imshow(img)
        plt.axis('off')
        plt.title(f"TANIMOTO: {tanimoto}, MCES pred: {40-(40*mces_pred)}, MZ= {Chem.rdMolDescriptors.CalcExactMolWt(mol)}")
        plt.show()
    else:
        print(f"Invalid SMILES string: {smiles}")

# %%
x_ranking= np.arange(0,len(mces_distance_list))
plt.bar(x_ranking,mces_distance_list)
plt.scatter(x_ranking, best_smiles_vector, marker="*", color="r")
plt.title(f'median distance: {np.median(mces_distance_list)}')
plt.xlabel('ranking')
plt.ylabel('mces distance - ground truth')
plt.ylim([0,50])

# %%
len(sim_k_retrieved)

# %%
x_ranking= np.arange(0,len(mces_distance_list))
plt.bar(x_ranking,sim_k_retrieved)
plt.xlabel('ranking')
plt.ylabel('model score')
plt.ylim([0,1.1])

# %%
from rdkit.Chem import Descriptors

precursor_mz_retrieved= np.array([Chem.Descriptors.ExactMolWt(Chem.MolFromSmiles(s)) for s in smiles_retrieved])
precursor_mz_query= Chem.Descriptors.ExactMolWt(Chem.MolFromSmiles(smiles_query))
diff_mz=np.abs(precursor_mz_retrieved-precursor_mz_query)
x_ranking= np.arange(0,len(mces_distance_list))
plt.bar(x_ranking,diff_mz, color='r')
plt.title(f'median diff mz:{np.median(diff_mz)}')
plt.xlabel('ranking')
plt.ylabel('diff mz')
plt.ylim([0, 100])

# %%
## sanity check: the average mces is the same for both?

# %%
## for a specific query, show the mces similarity for each one

# %%
# np.random.randint(0,10,100)

# %%
1/np.inf

# %%
}
